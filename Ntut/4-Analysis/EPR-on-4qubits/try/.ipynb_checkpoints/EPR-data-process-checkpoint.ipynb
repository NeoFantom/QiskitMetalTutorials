# %%
import numpy as np
import json

# %%
dataEPR = np.load('2023-02-17 20-57-15.npz', allow_pickle=True)
len(dataEPR)
# Out:
# 2

# %%
with open('pretty.txt', mode='w') as f:
    pprint(dataEPR, stream=f)

# %%
help(pprint)
# Out:
# Help on function pprint in module pprint:
#
# pprint(object, stream=None, indent=1, width=80, depth=None, *, compact=False, sort_dicts=True, underscore_numbers=False)
#     Pretty-print a Python object to a stream [default is sys.stdout].

# %%
pprint(dataEPR, width=200)
# Out:
# {'project_info': {'dissip': dielectrics_bulk       [main]
# dielectric_surfaces      None
# resistive_surfaces       None
# seams                    None
# dtype: object,
#                   'junctions':                                jj1                    jj2  \
# rect         JJ_rect_Lj_Q1_rect_jj  JJ_rect_Lj_Q2_rect_jj
# line             JJ_Lj_Q1_rect_jj_      JJ_Lj_Q2_rect_jj_
# Lj_variable                     Lj                     Lj
# Cj_variable                     Cj                     Cj
#
#                                jj3                    jj4
# rect         JJ_rect_Lj_Q3_rect_jj  JJ_rect_Lj_Q4_rect_jj
# line             JJ_Lj_Q3_rect_jj_      JJ_Lj_Q4_rect_jj_
# Lj_variable                     Lj                     Lj
# Cj_variable                     Cj                     Cj  ,
#                   'options': Series([], dtype: float64),
#                   'pinfo': design_name                                           EPR4qb_hfss
# ...

# %%
json.dumps(dataEPR)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 json.dumps(dataEPR)
#
# File ~\.conda\envs\qiskit-metal\lib\json\__init__.py:231, in dumps(obj, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, default, sort_keys, **kw)
#     226 # cached encoder
#     227 if (not skipkeys and ensure_ascii and
#     228     check_circular and allow_nan and
#     229     cls is None and indent is None and separators is None and
#     230     default is None and not sort_keys and not kw):
# --> 231     return _default_encoder.encode(obj)
#     232 if cls is None:
#     233     cls = JSONEncoder
#
# File ~\.conda\envs\qiskit-metal\lib\json\encoder.py:199, in JSONEncoder.encode(self, o)
#     195         return encode_basestring(o)
#     196 # This doesn't pass the iterator directly to ''.join() because the
# ...

# %%
pprint(dataEPR['results']['0'].keys(), width=200, indent=1)
# Out:
# dict_keys(['Pm', 'Pm_cap', 'Sm', 'Om', 'sols', 'Qm_coupling', 'Ljs', 'Cjs', 'Qs', 'freqs_hfss_GHz', 'hfss_variables', 'modes', 'I_peak', 'V_peak', 'ansys_energies', 'mesh', 'convergence', 'convergence_f_pass'])
