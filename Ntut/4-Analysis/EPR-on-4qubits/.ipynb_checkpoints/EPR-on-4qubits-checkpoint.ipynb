# %% [markdown]
# # EPR on 4 Qubits

# %% [markdown]
# ## 1. Create the design in Metal

# %%
# %reload_ext autoreload
# %autoreload 2

# %%
import qiskit_metal as metal
from qiskit_metal import designs, draw
from qiskit_metal import MetalGUI, Dict, Headings
from pprint import pprint
import pyEPR as epr

# %%
design = designs.DesignPlanar()
gui = MetalGUI(design)

from qiskit_metal.qlibrary.qubits.transmon_pocket import TransmonPocket
from qiskit_metal.qlibrary.tlines.meandered import RouteMeander

# %%
design.variables['cpw_width'] = '15 um'
design.variables['cpw_gap'] = '9 um'

# %% [markdown]
# ### In this example, the design consists of 4 qubits and 4 CPWs

# %%
# Allow running the same cell here multiple times to overwrite changes
design.overwrite_enabled = True

## Custom options for all the transmons
options = dict(
    # Some options we want to modify from the defaults
    # (see below for defaults)
    pad_width = '425 um', 
    pocket_height = '650um',
    # Adding 4 connectors (see below for defaults)
    connection_pads=dict(
        readout = dict(loc_W=+1,loc_H=-1, pad_width='200um'),
        bus1 = dict(loc_W=-1,loc_H=+1, pad_height='30um'),
        bus2 = dict(loc_W=-1,loc_H=-1, pad_height='50um')
    )
)

## Create 4 transmons

q1 = TransmonPocket(design, 'Q1', options = dict(
    pos_x='+2.42251mm', pos_y='+0.0mm', **options))
q2 = TransmonPocket(design, 'Q2', options = dict(
    pos_x='+0.0mm', pos_y='-0.95mm', orientation = '270', **options))
q3 = TransmonPocket(design, 'Q3', options = dict(
    pos_x='-2.42251mm', pos_y='+0.0mm', orientation = '180', **options))
q4 = TransmonPocket(design, 'Q4', options = dict(
    pos_x='+0.0mm', pos_y='+0.95mm', orientation = '90', **options))

RouteMeander.get_template_options(design)

options = Dict(
        lead=Dict(
            start_straight='0.2mm',
            end_straight='0.2mm'),
        trace_gap='9um',
        trace_width='15um')

def connect(component_name: str, component1: str, pin1: str, component2: str, pin2: str,
            length: str, asymmetry='0 um', flip=False, fillet='90um'):
    """Connect two pins with a CPW."""
    myoptions = Dict(
        fillet=fillet,
        hfss_wire_bonds = True,
        pin_inputs=Dict(
            start_pin=Dict(
                component=component1,
                pin=pin1),
            end_pin=Dict(
                component=component2,
                pin=pin2)),
        total_length=length)
    myoptions.update(options)
    myoptions.meander.asymmetry = asymmetry
    myoptions.meander.lead_direction_inverted = 'true' if flip else 'false'
    return RouteMeander(design, component_name, myoptions)

asym = 140
cpw1 = connect('cpw1', 'Q1', 'bus2', 'Q2', 'bus1', '6.0 mm', f'+{asym}um')
cpw2 = connect('cpw2', 'Q3', 'bus1', 'Q2', 'bus2', '6.1 mm', f'-{asym}um', flip=True)
cpw3 = connect('cpw3', 'Q3', 'bus2', 'Q4', 'bus1', '6.0 mm', f'+{asym}um')
cpw4 = connect('cpw4', 'Q1', 'bus1', 'Q4', 'bus2', '6.1 mm', f'-{asym}um', flip=True)

gui.rebuild()
gui.autoscale()
# Out:
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)

# %%
gui.screenshot()

# %%
design.qgeometry.tables['junction']
# Out:
#   component     name                                          geometry  layer  \
# 0         1  rect_jj    LINESTRING (2.42251 -0.01500, 2.42251 0.01500)      1
# 1         2  rect_jj  LINESTRING (-0.01500 -0.95000, 0.01500 -0.95000)      1
# 2         3  rect_jj  LINESTRING (-2.42251 0.01500, -2.42251 -0.01500)      1
# 3         4  rect_jj    LINESTRING (0.01500 0.95000, -0.01500 0.95000)      1
#
#    subtract  helper  chip  width hfss_inductance  hfss_capacitance  \
# 0     False   False  main   0.02            10nH                 0
# 1     False   False  main   0.02            10nH                 0
# 2     False   False  main   0.02            10nH                 0
# 3     False   False  main   0.02            10nH                 0
#
#    hfss_resistance  hfss_mesh_kw_jj q3d_inductance  q3d_capacitance  \
# 0                0         0.000007           10nH                0
# 1                0         0.000007           10nH                0
# 2                0         0.000007           10nH                0
# 3                0         0.000007           10nH                0
#
#    q3d_resistance  q3d_mesh_kw_jj      gds_cell_name
# 0               0        0.000007  my_other_junction
# 1               0        0.000007  my_other_junction
# 2               0        0.000007  my_other_junction
# 3               0        0.000007  my_other_junction

# %% [markdown]
# ## 2. Finite Element Eigenmode Analysis
#
# #### Setup
#
# Select the analysis you intend to run from the `qiskit_metal.analyses` collection.<br>
# Select the design to analyze and the tool to use for any external simulation.

# %%
from qiskit_metal.analyses.quantization import EPRanalysis

# %%
eig_qb = EPRanalysis(design, "hfss")

# %% [markdown]
# Review and update the convergence parameters and junction properties by executing following two cells. We exemplify three different methods to update the setup parameters.

# %%
eig_qb.sim.setup
# Out:
# {'name': 'Setup',
#  'reuse_selected_design': True,
#  'reuse_setup': True,
#  'min_freq_ghz': 1,
#  'n_modes': 8,
#  'max_delta_f': 0.5,
#  'max_passes': 10,
#  'min_passes': 1,
#  'min_converged': 1,
#  'pct_refinement': 30,
#  'basis_order': 1,
#  'vars': {'Lj': '10 nH', 'Cj': '0 fF'},
#  'run': {'name': 'EPR4qb',
#   'components': ['Q1', 'Q2', 'Q3', 'Q4', 'cpw1', 'cpw2', 'cpw3', 'cpw4'],
#   'open_terminations': [],
#   'port_list': None,
#   'jj_to_port': None,
#   'ignored_jjs': None,
#   'box_plus_buffer': False}}

# %%
# # -- settings --
# # example: update single setting
# eig_qb.sim.setup.max_passes = 6
# eig_qb.sim.setup.vars.Lj = '11 nH'
# # example: update multiple settings
# eig_qb.sim.setup_update(max_delta_f = 0.4, min_freq_ghz = 1.1)

eig_qb.sim.setup.n_modes = 8

eig_qb.sim.setup
# Out:
# {'name': 'Setup',
#  'reuse_selected_design': True,
#  'reuse_setup': True,
#  'min_freq_ghz': 1,
#  'n_modes': 8,
#  'max_delta_f': 0.5,
#  'max_passes': 10,
#  'min_passes': 1,
#  'min_converged': 1,
#  'pct_refinement': 30,
#  'basis_order': 1,
#  'vars': {'Lj': '10 nH', 'Cj': '0 fF'}}

# %% [markdown]
# #### Execute simulation and verify convergence and EM field
# Analyze a single qubit with shorted terminations. Then observe the frequency convergence plot. If not converging, you might want to increase the min_passes value to force the renderer to increase accuracy.
#
# You can use the method `run()` instead of `sim.run()` in the following cell if you want to run both eigenmode and epr analysis in a single step. If so, make sure to also tweak the setup for the epr analysis. The input parameters are otherwise the same for the two methods.

# %%
eig_qb.sim.run(name="EPR4qb", 
               components=['Q1', 'Q2', 'Q3', 'Q4', 'cpw1', 'cpw2', 'cpw3', 'cpw4'], 
               open_terminations=[], box_plus_buffer = False)
eig_qb.sim.plot_convergences()
# Out:
# INFO 09:42PM [connect_project]: Connecting to Ansys Desktop API...
# INFO 09:42PM [load_ansys_project]: 	Opened Ansys App
# INFO 09:42PM [load_ansys_project]: 	Opened Ansys Desktop v2021.2.0
# INFO 09:42PM [load_ansys_project]: 	Opened Ansys Project
# 	Folder:    C:/Users/neohu/Documents/Ansoft/
# 	Project:   Project2
# INFO 09:42PM [connect_design]: 	Opened active design
# 	Design:    Qbit_hfss [Solution type: Eigenmode]
# INFO 09:42PM [get_setup]: 	Opened setup `Setup`  (<class 'pyEPR.ansys.HfssEMSetup'>)
# INFO 09:42PM [connect]: 	Connected to project "Project2" and design "Qbit_hfss" 😀
#
# INFO 09:42PM [connect_design]: 	Opened active design
# 	Design:    EPR4qb_hfss [Solution type: Eigenmode]
# WARNING 09:42PM [connect_setup]: 	No design setup detected.
# WARNING 09:42PM [connect_setup]: 	Creating eigenmode default setup.
# INFO 09:42PM [get_setup]: 	Opened setup `Setup`  (<class 'pyEPR.ansys.HfssEMSetup'>)
# INFO 09:43PM [get_setup]: 	Opened setup `Setup`  (<class 'pyEPR.ansys.HfssEMSetup'>)
# INFO 09:43PM [analyze]: Analyzing setup Setup
# 09:52PM 55s INFO [get_f_convergence]: Saved convergences to C:\Users\neohu\Workspaces\QiskitMetalTutorials\Ntut\4-Analysis\EPR-on-4qubits\hfss_eig_f_convergence.csv

# %% [markdown]
# The last variables you pass to the `run()` or `sim.run()` methods, will be stored in the `sim.setup` dictionary under the key `run`. You can recall the information passed by either accessing the dictionary directly, or by using the print handle below.

# %%
# eig_qb.setup.run    <- direct access
eig_qb.sim.print_run_args()
# Out:
# This analysis object run with the following kwargs:
# {'name': 'EPR4qb', 'components': ['Q1', 'Q2', 'Q3', 'Q4', 'cpw1', 'cpw2', 'cpw3', 'cpw4'], 'open_terminations': [], 'port_list': None, 'jj_to_port': None, 'ignored_jjs': None, 'box_plus_buffer': False}

# %% [markdown]
# (optional) Captures the renderer GUI

# %%
eig_qb.sim.save_screenshot()
# Out:
# WindowsPath('C:/Users/neohu/Workspaces/QiskitMetalTutorials/Ntut/4-Analysis/EPR-on-4qubits/ansys.png')

# %% [markdown]
# (optional) Work directly with the convergence numbers

# %%
eig_qb.sim.convergence_f
# Out:
#          re(Mode(1)) [g]  re(Mode(2)) [g]  re(Mode(3)) [g]  re(Mode(4)) [g]  \
# Pass []
# 1               2.881014         3.445795         3.772940         4.088174
# 2               4.403686         4.531065         4.756070         4.834284
# 3               4.855059         5.194618         5.300276         5.377498
# 4               5.428448         5.584277         5.607398         5.626717
# 5               5.675613         5.739947         5.784559         5.795133
# 6               5.845318         5.875756         5.884715         5.893071
# 7               5.931594         5.938231         5.945710         5.954676
# 8               5.976473         5.987459         5.991939         6.006218
# 9               6.002910         6.018319         6.019566         6.034146
# 10              6.032889         6.043934         6.048014         6.062728
#
#          re(Mode(5)) [g]  re(Mode(6)) [g]  re(Mode(7)) [g]  re(Mode(8)) [g]
# Pass []
# 1               6.450265         6.740955         7.185017         7.445632
# 2               7.299693         7.379197         7.496974         7.944572
# 3               7.327462         7.705619         8.024500         8.118950
# 4               8.027024         8.049880         8.319667         8.374831
# 5               8.366819         8.416972         8.572501         8.638101
# 6               8.678679         8.699995         8.732657         8.773402
# 7               8.768855         8.835578         8.850857         8.899985
# 8               8.829102         8.873099         8.934569         8.950046
# 9               8.868868         8.887256         8.964922         8.982832
# 10              8.878403         8.886351         8.989245         8.997846

# %% [markdown]
# (optional) You can re-run the analysis after varying the parameters.<br>
# Not passing the parameter `components` to the `sim.run()` method, skips the rendering and tries to run the analysis on the latest design. If a design is not found, the full metal design is rendered.

# %%
# eig_qb.sim.setup.min_freq_ghz = 4
# eig_qb.sim.run()
# eig_qb.sim.convergence_f

# %% [markdown]
# ### 2.3 Verify that the Electro(magnetic) fields look realistic.

# %%
for modej in range(1, 9):
    print()
    print( '==============================')
    print(f'           mode {modej}             ')
    eig_qb.sim.plot_fields('main', eigenmode=modej)   # TODO:::: Ez, normal component.....decide which field typically on the qbit, or on the crossing between meanders
    eig_qb.sim.save_screenshot()
# Out:
# INFO 10:05PM [get_setup]: 	Opened setup `Setup`  (<class 'pyEPR.ansys.HfssEMSetup'>)
# ==============================
#            mode 1
# INFO 10:05PM [get_setup]: 	Opened setup `Setup`  (<class 'pyEPR.ansys.HfssEMSetup'>)
# ==============================
#            mode 2
# INFO 10:05PM [get_setup]: 	Opened setup `Setup`  (<class 'pyEPR.ansys.HfssEMSetup'>)
# ==============================
#            mode 3
# INFO 10:05PM [get_setup]: 	Opened setup `Setup`  (<class 'pyEPR.ansys.HfssEMSetup'>)
# ==============================
#            mode 4
# INFO 10:06PM [get_setup]: 	Opened setup `Setup`  (<class 'pyEPR.ansys.HfssEMSetup'>)
# ==============================
#            mode 5
# INFO 10:06PM [get_setup]: 	Opened setup `Setup`  (<class 'pyEPR.ansys.HfssEMSetup'>)
# ==============================
#            mode 6
# INFO 10:06PM [get_setup]: 	Opened setup `Setup`  (<class 'pyEPR.ansys.HfssEMSetup'>)
# ==============================
#            mode 7
# INFO 10:06PM [get_setup]: 	Opened setup `Setup`  (<class 'pyEPR.ansys.HfssEMSetup'>)
# ==============================
#            mode 8

# %% [markdown]
# (optional) clear the renderer by removing the fields

# %%
eig_qb.sim.clear_fields()

# %% [markdown]
# ## 3. EPR Analysis
# #### Setup
# Identify the non-linear (Josephson) junctions in the model. You will need to list the junctions in the epr setup.
#
# In this case there's only one junction, namely 'jj'. Let's see what we need to change in the default setup.

# %%
eig_qb.setup
# Out:
# {'junctions': {'jj1': {'rect': 'JJ_rect_Lj_Q1_rect_jj',
#    'line': 'JJ_Lj_Q1_rect_jj_',
#    'Lj_variable': 'Lj',
#    'Cj_variable': 'Cj'},
#   'jj2': {'rect': 'JJ_rect_Lj_Q2_rect_jj',
#    'line': 'JJ_Lj_Q2_rect_jj_',
#    'Lj_variable': 'Lj',
#    'Cj_variable': 'Cj'},
#   'jj3': {'rect': 'JJ_rect_Lj_Q3_rect_jj',
#    'line': 'JJ_Lj_Q3_rect_jj_',
#    'Lj_variable': 'Lj',
#    'Cj_variable': 'Cj'},
#   'jj4': {'rect': 'JJ_rect_Lj_Q4_rect_jj',
#    'line': 'JJ_Lj_Q4_rect_jj_',
#    'Lj_variable': 'Lj',
#    'Cj_variable': 'Cj'}},
#  'dissipatives': {'dielectrics_bulk': ['main']},
#  'cos_trunc': 8,
#  'fock_trunc': 7,
#  'sweep_variable': 'Lj'}

# %% [markdown]
# The name of the `Lj_variable` and `Cj_variable` match with our model. However it is missing the names of the shapes that identify the junction (`rect` and `line`). Look for those in the renderer and find the name. Then let's change the name (See below).

# %%
del eig_qb.setup.junctions['jj']
eig_qb.setup.junctions = {}
for jth_junction in range(1, 5):
    eig_qb.setup.junctions[f'jj{jth_junction}'] = Dict(rect=f'JJ_rect_Lj_Q{jth_junction}_rect_jj', 
                                       line=f'JJ_Lj_Q{jth_junction}_rect_jj_',
                                       Lj_variable='Lj', Cj_variable='Cj')
pprint(eig_qb.setup)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 del eig_qb.setup.junctions['jj']
#       2 eig_qb.setup.junctions = {}
#       3 for jth_junction in range(1, 5):
#
# KeyError: 'jj'

# %% [markdown]
# We will now run epr as a single step. On screen you will observe various information in this order:
# * stored energy = Electric and magnetic energy stored in the substrate and the system as a whole.
# * EPR analysis results for all modes/variations.
# * Spectrum analysis.
# * Hamiltonian report.

# %%
eig_qb.run_epr()

#### equivalent individual calls
# s = self.setup
# self.epr_start()
# eig_qb.get_stored_energy()
# eig_qb.run_analysis()
# eig_qb.spectrum_analysis(s.cos_trunc, s.fock_trunc)
# eig_qb.report_hamiltonian(s.swp_variable)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 eig_qb.run_epr()
#
# File c:\users\neohu\xandar\qiskit-metal\qiskit_metal\analyses\quantization\energy_participation_ratio.py:170, in EPRanalysis.run_epr(self, no_junctions)
#     167 # wipe data from the previous run (if any)
#     168 self.clear_data()
# --> 170 self.get_stored_energy(no_junctions)
#     171 if not no_junctions:
#     172     self.run_analysis()
#
# File c:\users\neohu\xandar\qiskit-metal\qiskit_metal\analyses\quantization\energy_participation_ratio.py:203, in EPRanalysis.get_stored_energy(self, no_junctions)
#     199 """Calculate the energy stored in the system based on the eigenmode results.
#     200 """
#     201 # execute EPR and energy extraction
#     202 self.energy_elec, self.energy_elec_sub, self.energy_mag = \
# --> 203     self.sim.renderer.epr_get_stored_energy(**self.epr_start(no_junctions))
#     205 # present a human-friendly output
#     206 print(f"""
#     207 energy_elec_all       = {self.energy_elec}
#     208 energy_elec_substrate = {self.energy_elec_sub}
#    (...)
#     212 energy_mag % of energy_elec_all  = {self.energy_mag / self.energy_elec * 100 :.1f}%
#     213 """)
#
# File c:\users\neohu\xandar\qiskit-metal\qiskit_metal\analyses\quantization\energy_participation_ratio.py:195, in EPRanalysis.epr_start(self, no_junctions)
#     191 system['junctions'] = {} if no_junctions else {
#     192     k: dict(v) for (k, v) in s.junctions.items()
#     193 }
#     194 system['dissipatives'] = dict(s.dissipatives)
# --> 195 self.sim.renderer.epr_start(**system)
#     196 return system
#
# File c:\users\neohu\xandar\qiskit-metal\qiskit_metal\renderers\renderer_ansys\ansys_renderer.py:1705, in QAnsysRenderer.epr_start(self, junctions, dissipatives)
#    1703         self.pinfo.junctions[k] = v
#    1704     # Check that valid names of variables and objects have been supplied
# -> 1705     self.pinfo.validate_junction_info()
#    1706 if dissipatives:
#    1707     for k, v in dissipatives.items():
#
# File ~\.conda\envs\qiskit-metal\lib\site-packages\pyEPR\project_info.py:481, in ProjectInfo.validate_junction_info(self)
#     473 assert jj['Lj_variable'] in all_variables_names,\
#     474     """pyEPR ProjectInfo user error found \N{face with medical mask}:
#     475     Seems like for junction `%s` you specified a design or project
#     476     variable for `Lj_variable` that does not exist in HFSS by the name:
#     477      `%s` """ % (jjnm, jj['Lj_variable'])
#     479 for name in ['rect', 'line']:
# --> 481     assert jj[name] in all_object_names, \
#     482         """pyEPR ProjectInfo user error found \N{face with medical mask}:
#     483         Seems like for junction `%s` you specified a %s that does not exist
#     484         in HFSS by the name: `%s` """ % (jjnm, name, jj[name])
#
# AssertionError: pyEPR ProjectInfo user error found 😷:
#                     Seems like for junction `jj` you specified a rect that does not exist
#                     in HFSS by the name: ``
