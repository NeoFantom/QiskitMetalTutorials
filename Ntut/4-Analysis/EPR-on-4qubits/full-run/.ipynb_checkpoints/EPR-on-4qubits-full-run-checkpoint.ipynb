# %% [markdown]
# # EPR on 4 Qubits

# %% [markdown]
# ## 1. Create the design in Metal

# %%
# %reload_ext autoreload
# %autoreload 2

# %%
import qiskit_metal as metal
from qiskit_metal import designs, draw
from qiskit_metal import MetalGUI, Dict, Headings
from pprint import pprint
import pyEPR as epr

# %%
design = designs.DesignPlanar()
gui = MetalGUI(design)

from qiskit_metal.qlibrary.qubits.transmon_pocket import TransmonPocket
from qiskit_metal.qlibrary.tlines.meandered import RouteMeander

# %%
design.variables['cpw_width'] = '15 um'
design.variables['cpw_gap'] = '9 um'

# %% [markdown]
# ### In this example, the design consists of 4 qubits and 4 CPWs

# %%
# Allow running the same cell here multiple times to overwrite changes
design.overwrite_enabled = True

## Custom options for all the transmons
options = dict(
    # Some options we want to modify from the defaults
    # (see below for defaults)
    pad_width = '425 um', 
    pocket_height = '650um',
    # Adding 4 connectors (see below for defaults)
    connection_pads=dict(
        readout = dict(loc_W=+1,loc_H=-1, pad_width='200um'),
        bus1 = dict(loc_W=-1,loc_H=+1, pad_height='30um'),
        bus2 = dict(loc_W=-1,loc_H=-1, pad_height='50um')
    )
)

## Create 4 transmons

q1 = TransmonPocket(design, 'Q1', options = dict(
    pos_x='+2.42251mm', pos_y='+0.0mm', **options))
q2 = TransmonPocket(design, 'Q2', options = dict(
    pos_x='+0.0mm', pos_y='-0.95mm', orientation = '270', **options))
q3 = TransmonPocket(design, 'Q3', options = dict(
    pos_x='-2.42251mm', pos_y='+0.0mm', orientation = '180', **options))
q4 = TransmonPocket(design, 'Q4', options = dict(
    pos_x='+0.0mm', pos_y='+0.95mm', orientation = '90', **options))

RouteMeander.get_template_options(design)

options = Dict(
        lead=Dict(
            start_straight='0.2mm',
            end_straight='0.2mm'),
        trace_gap='9um',
        trace_width='15um')

def connect(component_name: str, component1: str, pin1: str, component2: str, pin2: str,
            length: str, asymmetry='0 um', flip=False, fillet='90um'):
    """Connect two pins with a CPW."""
    myoptions = Dict(
        fillet=fillet,
        hfss_wire_bonds = True,
        pin_inputs=Dict(
            start_pin=Dict(
                component=component1,
                pin=pin1),
            end_pin=Dict(
                component=component2,
                pin=pin2)),
        total_length=length)
    myoptions.update(options)
    myoptions.meander.asymmetry = asymmetry
    myoptions.meander.lead_direction_inverted = 'true' if flip else 'false'
    return RouteMeander(design, component_name, myoptions)

asym = 140
cpw1 = connect('cpw1', 'Q1', 'bus2', 'Q2', 'bus1', '6.0 mm', f'+{asym}um')
cpw2 = connect('cpw2', 'Q3', 'bus1', 'Q2', 'bus2', '6.1 mm', f'-{asym}um', flip=True)
cpw3 = connect('cpw3', 'Q3', 'bus2', 'Q4', 'bus1', '6.0 mm', f'+{asym}um')
cpw4 = connect('cpw4', 'Q1', 'bus1', 'Q4', 'bus2', '6.1 mm', f'-{asym}um', flip=True)

gui.rebuild()
gui.autoscale()
# Out:
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
#
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)

# %%
gui.screenshot()

# %%
design.qgeometry.tables['junction']
# Out:
#   component     name                                          geometry  layer  \
# 0         1  rect_jj    LINESTRING (2.42251 -0.01500, 2.42251 0.01500)      1
# 1         2  rect_jj  LINESTRING (-0.01500 -0.95000, 0.01500 -0.95000)      1
# 2         3  rect_jj  LINESTRING (-2.42251 0.01500, -2.42251 -0.01500)      1
# 3         4  rect_jj    LINESTRING (0.01500 0.95000, -0.01500 0.95000)      1
#
#    subtract  helper  chip  width hfss_inductance  hfss_capacitance  \
# 0     False   False  main   0.02            10nH                 0
# 1     False   False  main   0.02            10nH                 0
# 2     False   False  main   0.02            10nH                 0
# 3     False   False  main   0.02            10nH                 0
#
#    hfss_resistance  hfss_mesh_kw_jj q3d_inductance  q3d_capacitance  \
# 0                0         0.000007           10nH                0
# 1                0         0.000007           10nH                0
# 2                0         0.000007           10nH                0
# 3                0         0.000007           10nH                0
#
#    q3d_resistance  q3d_mesh_kw_jj      gds_cell_name
# 0               0        0.000007  my_other_junction
# 1               0        0.000007  my_other_junction
# 2               0        0.000007  my_other_junction
# 3               0        0.000007  my_other_junction

# %% [markdown]
# ## 2. Finite Element Eigenmode Analysis
#
# #### Setup
#
# Select the analysis you intend to run from the `qiskit_metal.analyses` collection.<br>
# Select the design to analyze and the tool to use for any external simulation.

# %%
from qiskit_metal.analyses.quantization import EPRanalysis

# %%
eig_qb = EPRanalysis(design, "hfss")

# %% [markdown]
# Review and update the convergence parameters and junction properties by executing following two cells. We exemplify three different methods to update the setup parameters.

# %%
eig_qb.sim.setup
# Out:
# {'name': 'Setup',
#  'reuse_selected_design': True,
#  'reuse_setup': True,
#  'min_freq_ghz': 1,
#  'n_modes': 1,
#  'max_delta_f': 0.5,
#  'max_passes': 10,
#  'min_passes': 1,
#  'min_converged': 1,
#  'pct_refinement': 30,
#  'basis_order': 1,
#  'vars': {'Lj': '10 nH', 'Cj': '0 fF'}}

# %%
# # -- settings --
# # example: update single setting
# eig_qb.sim.setup.max_passes = 6
# eig_qb.sim.setup.vars.Lj = '11 nH'
# # example: update multiple settings
# eig_qb.sim.setup_update(max_delta_f = 0.4, min_freq_ghz = 1.1)

eig_qb.sim.setup.n_modes = 8

eig_qb.sim.setup
# Out:
# {'name': 'Setup',
#  'reuse_selected_design': True,
#  'reuse_setup': True,
#  'min_freq_ghz': 1,
#  'n_modes': 8,
#  'max_delta_f': 0.5,
#  'max_passes': 10,
#  'min_passes': 1,
#  'min_converged': 1,
#  'pct_refinement': 30,
#  'basis_order': 1,
#  'vars': {'Lj': '10 nH', 'Cj': '0 fF'}}

# %% [markdown]
# #### Execute simulation and verify convergence and EM field
# Analyze a single qubit with shorted terminations. Then observe the frequency convergence plot. If not converging, you might want to increase the min_passes value to force the renderer to increase accuracy.
#
# You can use the method `run()` instead of `sim.run()` in the following cell if you want to run both eigenmode and epr analysis in a single step. If so, make sure to also tweak the setup for the epr analysis. The input parameters are otherwise the same for the two methods.

# %%
eig_qb.sim.run(name="EPR4qb", 
               components=['Q1', 'Q2', 'Q3', 'Q4', 'cpw1', 'cpw2', 'cpw3', 'cpw4'], 
               open_terminations=[], box_plus_buffer = False)
eig_qb.sim.plot_convergences()
# Out:
# INFO 08:44PM [connect_project]: Connecting to Ansys Desktop API...
# INFO 08:44PM [load_ansys_project]: 	Opened Ansys App
# INFO 08:44PM [load_ansys_project]: 	Opened Ansys Desktop v2021.2.0
# INFO 08:44PM [load_ansys_project]: 	Opened Ansys Project
# 	Folder:    C:/Users/neohu/Workspaces/AnsysElectronics2021R2/
# 	Project:   Project2
# INFO 08:44PM [connect_design]: 	Opened active design
# 	Design:    EPR4qb_hfss [Solution type: Eigenmode]
# INFO 08:44PM [get_setup]: 	Opened setup `Setup`  (<class 'pyEPR.ansys.HfssEMSetup'>)
# INFO 08:44PM [connect]: 	Connected to project "Project2" and design "EPR4qb_hfss" 😀
#
# INFO 08:44PM [connect_design]: 	Opened active design
# 	Design:    EPR4qb_hfss [Solution type: Eigenmode]
# INFO 08:45PM [get_setup]: 	Opened setup `Setup`  (<class 'pyEPR.ansys.HfssEMSetup'>)
# INFO 08:45PM [analyze]: Analyzing setup Setup
# 08:55PM 35s INFO [get_f_convergence]: Saved convergences to C:\Users\neohu\Workspaces\QiskitMetalTutorials\Ntut\4-Analysis\EPR-on-4qubits\hfss_eig_f_convergence.csv

# %% [markdown]
# The last variables you pass to the `run()` or `sim.run()` methods, will be stored in the `sim.setup` dictionary under the key `run`. You can recall the information passed by either accessing the dictionary directly, or by using the print handle below.

# %%
# eig_qb.setup.run    <- direct access
eig_qb.sim.print_run_args()
# Out:
# This analysis object run with the following kwargs:
# {'name': 'EPR4qb', 'components': ['Q1', 'Q2', 'Q3', 'Q4', 'cpw1', 'cpw2', 'cpw3', 'cpw4'], 'open_terminations': [], 'port_list': None, 'jj_to_port': None, 'ignored_jjs': None, 'box_plus_buffer': False}

# %% [markdown]
# (optional) Captures the renderer GUI

# %%
eig_qb.sim.save_screenshot()
# Out:
# WindowsPath('C:/Users/neohu/Workspaces/QiskitMetalTutorials/Ntut/4-Analysis/EPR-on-4qubits/ansys.png')

# %% [markdown]
# (optional) Work directly with the convergence numbers

# %%
eig_qb.sim.convergence_f
# Out:
#          re(Mode(1)) [g]  re(Mode(2)) [g]  re(Mode(3)) [g]  re(Mode(4)) [g]  \
# Pass []
# 1               3.535686         3.599846         3.835934         3.949075
# 2               4.407345         4.479476         4.542370         4.800178
# 3               5.172132         5.180506         5.193628         5.325210
# 4               5.450494         5.552334         5.563663         5.594547
# 5               5.714693         5.744712         5.761632         5.774348
# 6               5.821657         5.850456         5.865722         5.880487
# 7               5.889097         5.928646         5.942553         5.958538
# 8               5.932034         5.972507         5.991439         6.000728
# 9               5.985149         6.016711         6.020755         6.031610
# 10              6.025814         6.046565         6.049369         6.059445
#
#          re(Mode(5)) [g]  re(Mode(6)) [g]  re(Mode(7)) [g]  re(Mode(8)) [g]
# Pass []
# 1               5.762292         6.582197         6.966249         7.172108
# 2               6.344418         7.260263         7.527766         7.609975
# 3               7.195407         7.792656         7.946249         7.958051
# 4               7.636304         8.264703         8.291800         8.382677
# 5               8.316468         8.491407         8.562055         8.676022
# 6               8.586962         8.633916         8.711014         8.801393
# 7               8.747496         8.778111         8.801702         8.902006
# 8               8.824042         8.843468         8.909458         8.951873
# 9               8.850478         8.881058         8.941220         8.985738
# 10              8.868567         8.883398         8.980888         8.996321

# %% [markdown]
# (optional) You can re-run the analysis after varying the parameters.<br>
# Not passing the parameter `components` to the `sim.run()` method, skips the rendering and tries to run the analysis on the latest design. If a design is not found, the full metal design is rendered.

# %%
# eig_qb.sim.setup.min_freq_ghz = 4
# eig_qb.sim.run()
# eig_qb.sim.convergence_f

# %% [markdown]
# ### 2.3 Verify that the Electro(magnetic) fields look realistic.

# %%
for modej in range(1, 9):
    print()
    print( '==============================')
    print(f'           mode {modej}             ')
    eig_qb.sim.plot_fields('main', eigenmode=modej)   # TODO:::: Ez, normal component.....decide which field typically on the qbit, or on the crossing between meanders
    eig_qb.sim.save_screenshot()
# Out:
# INFO 08:55PM [get_setup]: 	Opened setup `Setup`  (<class 'pyEPR.ansys.HfssEMSetup'>)
# ==============================
#            mode 1
# INFO 08:55PM [get_setup]: 	Opened setup `Setup`  (<class 'pyEPR.ansys.HfssEMSetup'>)
# ==============================
#            mode 2
# INFO 08:55PM [get_setup]: 	Opened setup `Setup`  (<class 'pyEPR.ansys.HfssEMSetup'>)
# ==============================
#            mode 3
# INFO 08:56PM [get_setup]: 	Opened setup `Setup`  (<class 'pyEPR.ansys.HfssEMSetup'>)
# ==============================
#            mode 4
# ==============================
#            mode 5
# INFO 08:56PM [get_setup]: 	Opened setup `Setup`  (<class 'pyEPR.ansys.HfssEMSetup'>)
# ==============================
#            mode 6
# INFO 08:56PM [get_setup]: 	Opened setup `Setup`  (<class 'pyEPR.ansys.HfssEMSetup'>)
# ==============================
#            mode 7
# INFO 08:56PM [get_setup]: 	Opened setup `Setup`  (<class 'pyEPR.ansys.HfssEMSetup'>)
# ==============================
#            mode 8
# INFO 08:56PM [get_setup]: 	Opened setup `Setup`  (<class 'pyEPR.ansys.HfssEMSetup'>)

# %% [markdown]
# (optional) clear the renderer by removing the fields

# %%
eig_qb.sim.clear_fields()

# %% [markdown]
# ## 3. EPR Analysis
# #### Setup
# Identify the non-linear (Josephson) junctions in the model. You will need to list the junctions in the epr setup.
#
# In this case there's only one junction, namely 'jj'. Let's see what we need to change in the default setup.

# %%
eig_qb.setup
# Out:
# {'junctions': {'jj': {'Lj_variable': 'Lj',
#    'Cj_variable': 'Cj',
#    'rect': '',
#    'line': ''}},
#  'dissipatives': {'dielectrics_bulk': ['main']},
#  'cos_trunc': 8,
#  'fock_trunc': 7,
#  'sweep_variable': 'Lj'}

# %% [markdown]
# The name of the `Lj_variable` and `Cj_variable` match with our model. However it is missing the names of the shapes that identify the junction (`rect` and `line`). Look for those in the renderer and find the name. Then let's change the name (See below).

# %%
del eig_qb.setup.junctions['jj']
eig_qb.setup.junctions = {}
for jth_junction in range(1, 5):
    eig_qb.setup.junctions[f'jj{jth_junction}'] = Dict(rect=f'JJ_rect_Lj_Q{jth_junction}_rect_jj', 
                                       line=f'JJ_Lj_Q{jth_junction}_rect_jj_',
                                       Lj_variable='Lj', Cj_variable='Cj')
pprint(eig_qb.setup)
# Out:
# {'cos_trunc': 8,
#  'dissipatives': {'dielectrics_bulk': ['main']},
#  'fock_trunc': 7,
#  'junctions': {'jj1': {'Cj_variable': 'Cj',
#                        'Lj_variable': 'Lj',
#                        'line': 'JJ_Lj_Q1_rect_jj_',
#                        'rect': 'JJ_rect_Lj_Q1_rect_jj'},
#                'jj2': {'Cj_variable': 'Cj',
#                        'Lj_variable': 'Lj',
#                        'line': 'JJ_Lj_Q2_rect_jj_',
#                        'rect': 'JJ_rect_Lj_Q2_rect_jj'},
#                'jj3': {'Cj_variable': 'Cj',
#                        'Lj_variable': 'Lj',
#                        'line': 'JJ_Lj_Q3_rect_jj_',
#                        'rect': 'JJ_rect_Lj_Q3_rect_jj'},
#                'jj4': {'Cj_variable': 'Cj',
#                        'Lj_variable': 'Lj',
#                        'line': 'JJ_Lj_Q4_rect_jj_',
#                        'rect': 'JJ_rect_Lj_Q4_rect_jj'}},
#  'sweep_variable': 'Lj'}

# %% [markdown]
# We will now run epr as a single step. On screen you will observe various information in this order:
# * stored energy = Electric and magnetic energy stored in the substrate and the system as a whole.
# * EPR analysis results for all modes/variations.
# * Spectrum analysis.
# * Hamiltonian report.

# %%
eig_qb.run_epr()

#### equivalent individual calls
# s = self.setup
# self.epr_start()
# eig_qb.get_stored_energy()
# eig_qb.run_analysis()
# eig_qb.spectrum_analysis(s.cos_trunc, s.fock_trunc)
# eig_qb.report_hamiltonian(s.swp_variable)
# Out:
# Design "EPR4qb_hfss" info:
# 	# eigenmodes    8
# 	# variations    1
# Design "EPR4qb_hfss" info:
# 	# eigenmodes    8
# 	# variations    1
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pyEPR\project_info.py:239: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   options=pd.Series(get_instance_vars(self.options)),
#         energy_elec_all       = 6.93642589620847e-24
#         energy_elec_substrate = 6.3516822365016e-24
#         EPR of substrate = 91.6%
#
#         energy_mag    = 6.91577528758792e-24
#         energy_mag % of energy_elec_all  = 99.7%
#
#
# Variation 0  [1/1]
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pyEPR\core_distributed_analysis.py:1101: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   Ljs = pd.Series({})
#
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pyEPR\core_distributed_analysis.py:1102: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   Cjs = pd.Series({})
#
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pyEPR\core_distributed_analysis.py:1245: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   _Om = pd.Series({})
#   Mode 0 at 6.03 GHz   [1/8]
#     Calculating ℰ_magnetic,ℰ_electric
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pyEPR\core_distributed_analysis.py:981: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   Sj = pd.Series({})
#        (ℰ_E-ℰ_H)/ℰ_E       ℰ_E       ℰ_H
#                98.8%  4.085e-24 4.744e-26
#
#     Calculating junction energy participation ration (EPR)
# 	method=`line_voltage`. First estimates:
# 	junction        EPR p_0j   sign s_0j    (p_capacitive)
# 		Energy fraction (Lj over Lj&Cj)= 97.21%
# 	jj1             0.00372062  (+)        0.000106669
# 		Energy fraction (Lj over Lj&Cj)= 97.21%
# 	jj2             0.0364641  (+)        0.00104541
# 		Energy fraction (Lj over Lj&Cj)= 97.21%
# 	jj3             0.908495  (+)        0.0260462
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pyEPR\core_distributed_analysis.py:933: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   Qp = pd.Series({})
# 		Energy fraction (Lj over Lj&Cj)= 97.21%
# 	jj4             0.0384535  (+)        0.00110245
# 		(U_tot_cap-U_tot_ind)/mean=1.46%
# Calculating Qdielectric_main for mode 0 (0/7)
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pyEPR\core_distributed_analysis.py:1307: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   sol = sol.append(self.get_Qdielectric(
# p_dielectric_main_0 = 0.9172933270749704
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pyEPR\core_distributed_analysis.py:1245: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   _Om = pd.Series({})
#   Mode 1 at 6.05 GHz   [2/8]
#     Calculating ℰ_magnetic,ℰ_electric
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pyEPR\core_distributed_analysis.py:981: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   Sj = pd.Series({})
#        (ℰ_E-ℰ_H)/ℰ_E       ℰ_E       ℰ_H
#                98.9%  7.505e-24 8.577e-26
#
#     Calculating junction energy participation ration (EPR)
# 	method=`line_voltage`. First estimates:
# 	junction        EPR p_1j   sign s_1j    (p_capacitive)
# 		Energy fraction (Lj over Lj&Cj)= 97.19%
# 	jj1             0.341416  (+)        0.00985577
# 		Energy fraction (Lj over Lj&Cj)= 97.19%
# 	jj2             0.195844  (+)        0.00565349
# 		Energy fraction (Lj over Lj&Cj)= 97.19%
# 	jj3             0.0654034  (+)        0.00188802
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pyEPR\core_distributed_analysis.py:933: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   Qp = pd.Series({})
# 		Energy fraction (Lj over Lj&Cj)= 97.19%
# 	jj4             0.385146  (+)        0.0111181
# 		(U_tot_cap-U_tot_ind)/mean=1.44%
# Calculating Qdielectric_main for mode 1 (1/7)
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pyEPR\core_distributed_analysis.py:1307: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   sol = sol.append(self.get_Qdielectric(
#
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pyEPR\core_distributed_analysis.py:1245: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   _Om = pd.Series({})
# p_dielectric_main_1 = 0.917842709730477
#
#   Mode 2 at 6.05 GHz   [3/8]
#     Calculating ℰ_magnetic,ℰ_electric
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pyEPR\core_distributed_analysis.py:981: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   Sj = pd.Series({})
#        (ℰ_E-ℰ_H)/ℰ_E       ℰ_E       ℰ_H
#                99.0%   4.76e-24 4.876e-26
#
#     Calculating junction energy participation ration (EPR)
# 	method=`line_voltage`. First estimates:
# 	junction        EPR p_2j   sign s_2j    (p_capacitive)
# 		Energy fraction (Lj over Lj&Cj)= 97.19%
# 	jj1             0.00844346  (+)        0.000243966
# 		Energy fraction (Lj over Lj&Cj)= 97.19%
# 	jj2             0.573469  (+)        0.0165699
# 		Energy fraction (Lj over Lj&Cj)= 97.19%
# 	jj3             0.000711965  (+)        2.05716e-05
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pyEPR\core_distributed_analysis.py:933: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   Qp = pd.Series({})
# 		Energy fraction (Lj over Lj&Cj)= 97.19%
# 	jj4             0.406765  (+)        0.0117531
# 		(U_tot_cap-U_tot_ind)/mean=1.43%
# Calculating Qdielectric_main for mode 2 (2/7)
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pyEPR\core_distributed_analysis.py:1307: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   sol = sol.append(self.get_Qdielectric(
# p_dielectric_main_2 = 0.9177600709556929
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pyEPR\core_distributed_analysis.py:1245: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   _Om = pd.Series({})
#   Mode 3 at 6.06 GHz   [4/8]
#     Calculating ℰ_magnetic,ℰ_electric
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pyEPR\core_distributed_analysis.py:981: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   Sj = pd.Series({})
#        (ℰ_E-ℰ_H)/ℰ_E       ℰ_E       ℰ_H
#                99.2%  4.666e-24 3.508e-26
#
#     Calculating junction energy participation ration (EPR)
# 	method=`line_voltage`. First estimates:
# 	junction        EPR p_3j   sign s_3j    (p_capacitive)
# 		Energy fraction (Lj over Lj&Cj)= 97.18%
# 	jj1             0.634937  (+)        0.0184071
# 		Energy fraction (Lj over Lj&Cj)= 97.18%
# 	jj2             0.183681  (+)        0.005325
# 		Energy fraction (Lj over Lj&Cj)= 97.18%
# 	jj3             0.0138374  (+)        0.000401153
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pyEPR\core_distributed_analysis.py:933: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   Qp = pd.Series({})
# 		Energy fraction (Lj over Lj&Cj)= 97.18%
# 	jj4             0.159033  (+)        0.00461043
# 		(U_tot_cap-U_tot_ind)/mean=1.47%
# Calculating Qdielectric_main for mode 3 (3/7)
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pyEPR\core_distributed_analysis.py:1307: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   sol = sol.append(self.get_Qdielectric(
# p_dielectric_main_3 = 0.9183955182889093
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pyEPR\core_distributed_analysis.py:1245: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   _Om = pd.Series({})
#   Mode 4 at 8.87 GHz   [5/8]
#     Calculating ℰ_magnetic,ℰ_electric
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pyEPR\core_distributed_analysis.py:981: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   Sj = pd.Series({})
#        (ℰ_E-ℰ_H)/ℰ_E       ℰ_E       ℰ_H
#                 0.5%  4.666e-24 4.645e-24
#
#     Calculating junction energy participation ration (EPR)
# 	method=`line_voltage`. First estimates:
# 	junction        EPR p_4j   sign s_4j    (p_capacitive)
# 		Energy fraction (Lj over Lj&Cj)= 94.15%
# 	jj1             2.58685e-05  (+)        1.60645e-06
# 		Energy fraction (Lj over Lj&Cj)= 94.15%
# 	jj2             0.00186317  (+)        0.000115704
# 		Energy fraction (Lj over Lj&Cj)= 94.15%
# 	jj3             0.00264201  (+)        0.000164071
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pyEPR\core_distributed_analysis.py:933: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   Qp = pd.Series({})
# 		Energy fraction (Lj over Lj&Cj)= 94.15%
# 	jj4             2.6777e-05  (+)        1.66287e-06
# 		(U_tot_cap-U_tot_ind)/mean=0.01%
# Calculating Qdielectric_main for mode 4 (4/7)
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pyEPR\core_distributed_analysis.py:1307: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   sol = sol.append(self.get_Qdielectric(
#
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pyEPR\core_distributed_analysis.py:1245: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   _Om = pd.Series({})
# p_dielectric_main_4 = 0.9159006742033282
#
#   Mode 5 at 8.88 GHz   [6/8]
#     Calculating ℰ_magnetic,ℰ_electric
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pyEPR\core_distributed_analysis.py:981: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   Sj = pd.Series({})
#        (ℰ_E-ℰ_H)/ℰ_E       ℰ_E       ℰ_H
#                 0.5%  3.893e-24 3.876e-24
#
#     Calculating junction energy participation ration (EPR)
# 	method=`line_voltage`. First estimates:
# 	junction        EPR p_5j   sign s_5j    (p_capacitive)
# 		Energy fraction (Lj over Lj&Cj)= 94.13%
# 	jj1             0.00261308  (+)        0.000162817
# 		Energy fraction (Lj over Lj&Cj)= 94.13%
# 	jj2             1.19836e-06  (+)        7.46679e-08
# 		Energy fraction (Lj over Lj&Cj)= 94.13%
# 	jj3             1.6662e-06  (+)        1.03819e-07
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pyEPR\core_distributed_analysis.py:933: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   Qp = pd.Series({})
# 		Energy fraction (Lj over Lj&Cj)= 94.13%
# 	jj4             0.00192638  (+)        0.00012003
# 		(U_tot_cap-U_tot_ind)/mean=0.01%
# Calculating Qdielectric_main for mode 5 (5/7)
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pyEPR\core_distributed_analysis.py:1307: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   sol = sol.append(self.get_Qdielectric(
# p_dielectric_main_5 = 0.9149362978255999
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pyEPR\core_distributed_analysis.py:1245: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   _Om = pd.Series({})
#   Mode 6 at 8.98 GHz   [7/8]
#     Calculating ℰ_magnetic,ℰ_electric
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pyEPR\core_distributed_analysis.py:981: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   Sj = pd.Series({})
#        (ℰ_E-ℰ_H)/ℰ_E       ℰ_E       ℰ_H
#                 0.3%  4.304e-24  4.29e-24
#
#     Calculating junction energy participation ration (EPR)
# 	method=`line_voltage`. First estimates:
# 	junction        EPR p_6j   sign s_6j    (p_capacitive)
# 		Energy fraction (Lj over Lj&Cj)= 94.01%
# 	jj1             0.000106324  (+)        6.77109e-06
# 		Energy fraction (Lj over Lj&Cj)= 94.01%
# 	jj2             9.54253e-05  (+)        6.07704e-06
# 		Energy fraction (Lj over Lj&Cj)= 94.01%
# 	jj3             0.00119038  (+)        7.58078e-05
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pyEPR\core_distributed_analysis.py:933: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   Qp = pd.Series({})
# 		Energy fraction (Lj over Lj&Cj)= 94.01%
# 	jj4             0.00190706  (+)        0.000121449
# 		(U_tot_cap-U_tot_ind)/mean=0.01%
# Calculating Qdielectric_main for mode 6 (6/7)
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pyEPR\core_distributed_analysis.py:1307: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   sol = sol.append(self.get_Qdielectric(
#
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pyEPR\core_distributed_analysis.py:1245: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   _Om = pd.Series({})
# p_dielectric_main_6 = 0.9161966666130104
#
#   Mode 7 at 9.00 GHz   [8/8]
#     Calculating ℰ_magnetic,ℰ_electric
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pyEPR\core_distributed_analysis.py:981: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   Sj = pd.Series({})
#        (ℰ_E-ℰ_H)/ℰ_E       ℰ_E       ℰ_H
#                 0.3%  3.468e-24 3.458e-24
#
#     Calculating junction energy participation ration (EPR)
# 	method=`line_voltage`. First estimates:
# 	junction        EPR p_7j   sign s_7j    (p_capacitive)
# 		Energy fraction (Lj over Lj&Cj)= 93.99%
# 	jj1             0.00110859  (+)        7.08418e-05
# 		Energy fraction (Lj over Lj&Cj)= 93.99%
# 	jj2             0.00189701  (+)        0.000121224
# 		Energy fraction (Lj over Lj&Cj)= 93.99%
# 	jj3             1.35873e-06  (+)        8.68269e-08
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pyEPR\core_distributed_analysis.py:933: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   Qp = pd.Series({})
# 		Energy fraction (Lj over Lj&Cj)= 93.99%
# 	jj4             1.17907e-05  (+)        7.53459e-07
# 		(U_tot_cap-U_tot_ind)/mean=0.01%
# Calculating Qdielectric_main for mode 7 (7/7)
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pyEPR\core_distributed_analysis.py:1307: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   sol = sol.append(self.get_Qdielectric(
# p_dielectric_main_7 = 0.9156995737492852
# WARNING:py.warnings:C:\Users\neohu\.conda\envs\qiskit-metal\lib\site-packages\pyEPR\project_info.py:239: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   options=pd.Series(get_instance_vars(self.options)),
#
# WARNING 08:58PM [__init__]: <p>Error: <class 'IndexError'></p>
# ANALYSIS DONE. Data saved to:
#
# C:\data-pyEPR\Project2\EPR4qb_hfss\2023-02-17 20-57-15.npz
#
#
# 	 Differences in variations:
#
#
#
#  . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
# Variation 0

# %%
print('ALL IS WELL')
# Out:
# ALL IS WELL
